# %% [markdown]
# # Data Extraction from a pdf file using tabula
# *tabula library is used to extract tables from pdf file <br>
# *for installation: type <b>pip install tabula-py</b> in anaconda terminal

# %%
from tabula import read_pdf

# %%
#extracting tables from a pdf file
#by default it will extract the table from first page only
df= read_pdf(r"C:\\Users\\owner\\Desktop\\Food Calories List.pdf")
df
# Out:
#               BREADS & CEREALS               Portion size *  \
# 0          Bagel ( 1 average )               140 cals (45g)
# 1           Biscuit digestives        86 cals (per biscuit)
# 2                   Jaffa cake        48 cals (per biscuit)
# 3    Bread white (thick slice)       96  cals (1 slice 40g)
# 4      Bread wholemeal (thick)       88  cals (1 slice 40g)
# 5                     Chapatis                     250 cals
# 6                   Cornflakes              130  cals (35g)
# 7                 Crackerbread            17 cals per slice
# 8               Cream crackers        35 cals (per cracker)
# 9                     Crumpets        93 cals (per crumpet)
# 10   Flapjacks basic fruit mix                     320 cals
# 11           Macaroni (boiled)              238 cals (250g)
# 12                      Muesli              195  cals (50g)
# 13         Naan bread (normal)  300 cals (small plate size)
# 14            Noodles (boiled)              175 cals (250g)
# 15     Pasta ( normal boiled )              330 cals (300g)
# 16   Pasta (wholemeal boiled )              315 cals (300g)
# 17  Porridge oats (with water)              193 cals (350g)
# 18         Potatoes** (boiled)              210 cals (300g)
# 19          Potatoes** (roast)              420 cals (300g)
#
#    per 100 grams (3.5 oz)  Unnamed: 3 energy content
# 0                310 cals         NaN         Medium
# 1                480 cals         NaN           High
# 2                370 cals         NaN       Med-High
# 3                240 cals         NaN         Medium
# 4                220 cals         NaN        Low-med
# 5                300 cals         NaN         Medium
# 6                370 cals         NaN       Med-High
# 7                325 cals         NaN    Low Calorie
# 8                440 cals         NaN  Low / portion
# 9                198 cals         NaN        Low-Med
# 10               500 cals         NaN           High
# 11                95 cals         NaN    Low calorie
# 12               390 cals         NaN       Med-high
# 13               320 cals         NaN         Medium
# 14                70 cals         NaN    Low calorie
# 15               110 cals         NaN    Low calorie
# 16               105 cals         NaN    Low calorie
# 17                55 cals         NaN    Low calorie
# 18                70 cals         NaN    Low calorie
# 19               140 cals         NaN         Medium

# %%
#dropping the null values
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#               BREADS & CEREALS               Portion size *  \
# 0          Bagel ( 1 average )               140 cals (45g)
# 1           Biscuit digestives        86 cals (per biscuit)
# 2                   Jaffa cake        48 cals (per biscuit)
# 3    Bread white (thick slice)       96  cals (1 slice 40g)
# 4      Bread wholemeal (thick)       88  cals (1 slice 40g)
# 5                     Chapatis                     250 cals
# 6                   Cornflakes              130  cals (35g)
# 7                 Crackerbread            17 cals per slice
# 8               Cream crackers        35 cals (per cracker)
# 9                     Crumpets        93 cals (per crumpet)
# 10   Flapjacks basic fruit mix                     320 cals
# 11           Macaroni (boiled)              238 cals (250g)
# 12                      Muesli              195  cals (50g)
# 13         Naan bread (normal)  300 cals (small plate size)
# 14            Noodles (boiled)              175 cals (250g)
# 15     Pasta ( normal boiled )              330 cals (300g)
# 16   Pasta (wholemeal boiled )              315 cals (300g)
# 17  Porridge oats (with water)              193 cals (350g)
# 18         Potatoes** (boiled)              210 cals (300g)
# 19          Potatoes** (roast)              420 cals (300g)
#
#    per 100 grams (3.5 oz) energy content
# 0                310 cals         Medium
# 1                480 cals           High
# 2                370 cals       Med-High
# 3                240 cals         Medium
# 4                220 cals        Low-med
# 5                300 cals         Medium
# 6                370 cals       Med-High
# 7                325 cals    Low Calorie
# 8                440 cals  Low / portion
# 9                198 cals        Low-Med
# 10               500 cals           High
# 11                95 cals    Low calorie
# 12               390 cals       Med-high
# 13               320 cals         Medium
# 14                70 cals    Low calorie
# 15               110 cals    Low calorie
# 16               105 cals    Low calorie
# 17                55 cals    Low calorie
# 18                70 cals    Low calorie
# 19               140 cals         Medium

# %%
#extracting the first page and getting the output in json format
df_json= read_pdf(r"C:\\Users\\owner\\Desktop\\Food Calories List.pdf", output_format='json')
df_json
# Out:
# [{'extraction_method': 'stream',
#   'top': 227.0,
#   'left': 55.0,
#   'width': 499.0,
#   'height': 488.0,
#   'right': 554.0,
#   'bottom': 715.0,
#   'data': [[{'top': 243.08,
#      'left': 78.0,
#      'width': 124.32000732421875,
#      'height': 7.960000038146973,
#      'text': 'BREADS & CEREALS'},
#     {'top': 243.08,
#      'left': 261.36,
#      'width': 72.36001586914062,
#      'height': 7.960000038146973,
#      'text': 'Portion size *'},
#     {'top': 236.12,
#      'left': 376.68,
#      'width': 76.20001220703125,
#      'height': 21.76000213623047,
#      'text': 'per 100 grams (3.5 oz)'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 243.08,
#      'left': 467.88,
#      'width': 78.5999755859375,
#      'height': 7.960000038146973,
#      'text': 'energy content'}],
#    [{'top': 272.07,
#      'left': 93.0,
#      'width': 94.32000732421875,
#      'height': 7.880000114440918,
#      'text': 'Bagel ( 1 average )'},
#     {'top': 272.07,
#      'left': 261.72,
#      'width': 71.63998413085938,
#      'height': 7.880000114440918,
#      'text': '140 cals (45g)'},
#     {'top': 272.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '310 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 272.07,
#      'left': 485.28,
#      'width': 43.680023193359375,
#      'height': 7.880000114440918,
#      'text': 'Medium'}],
#    [{'top': 294.63,
#      'left': 96.24,
#      'width': 90.95999908447266,
#      'height': 7.880000114440918,
#      'text': 'Biscuit digestives'},
#     {'top': 294.63,
#      'left': 248.52,
#      'width': 97.91999816894531,
#      'height': 7.880000114440918,
#      'text': '86 cals (per biscuit)'},
#     {'top': 294.63,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '480 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 294.63,
#      'left': 493.68,
#      'width': 27.0,
#      'height': 7.880000114440918,
#      'text': 'High'}],
#    [{'top': 317.07,
#      'left': 114.6,
#      'width': 51.23999786376953,
#      'height': 7.880000114440918,
#      'text': 'Jaffa cake'},
#     {'top': 317.07,
#      'left': 248.52,
#      'width': 97.91999816894531,
#      'height': 7.880000114440918,
#      'text': '48 cals (per biscuit)'},
#     {'top': 317.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '370 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 317.07,
#      'left': 480.6,
#      'width': 53.040008544921875,
#      'height': 7.880000114440918,
#      'text': 'Med-High'}],
#    [{'top': 339.63,
#      'left': 79.56,
#      'width': 121.32000732421875,
#      'height': 7.880000114440918,
#      'text': 'Bread white (thick slice)'},
#     {'top': 339.63,
#      'left': 246.24,
#      'width': 102.59999084472656,
#      'height': 7.880000114440918,
#      'text': '96  cals (1 slice 40g)'},
#     {'top': 339.63,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '240 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 339.63,
#      'left': 485.28,
#      'width': 43.680023193359375,
#      'height': 7.880000114440918,
#      'text': 'Medium'}],
#    [{'top': 362.07,
#      'left': 79.08,
#      'width': 122.27999877929688,
#      'height': 7.880000114440918,
#      'text': 'Bread wholemeal (thick)'},
#     {'top': 362.07,
#      'left': 246.24,
#      'width': 102.59999084472656,
#      'height': 7.880000114440918,
#      'text': '88  cals (1 slice 40g)'},
#     {'top': 362.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '220 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 362.07,
#      'left': 482.28,
#      'width': 49.680023193359375,
#      'height': 7.880000114440918,
#      'text': 'Low-med'}],
#    [{'top': 384.63,
#      'left': 117.72,
#      'width': 45.0,
#      'height': 7.880000114440918,
#      'text': 'Chapatis'},
#     {'top': 384.63,
#      'left': 276.24,
#      'width': 42.600006103515625,
#      'height': 7.880000114440918,
#      'text': '250 cals'},
#     {'top': 384.63,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '300 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 384.63,
#      'left': 485.28,
#      'width': 43.680023193359375,
#      'height': 7.880000114440918,
#      'text': 'Medium'}],
#    [{'top': 407.07,
#      'left': 112.32,
#      'width': 55.68000030517578,
#      'height': 7.880000114440918,
#      'text': 'Cornflakes'},
#     {'top': 407.07,
#      'left': 260.16,
#      'width': 74.63998413085938,
#      'height': 7.880000114440918,
#      'text': '130  cals (35g)'},
#     {'top': 407.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '370 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 407.07,
#      'left': 480.6,
#      'width': 53.040008544921875,
#      'height': 7.880000114440918,
#      'text': 'Med-High'}],
#    [{'top': 429.63,
#      'left': 106.32,
#      'width': 67.68000030517578,
#      'height': 7.880000114440918,
#      'text': 'Crackerbread'},
#     {'top': 429.63,
#      'left': 257.52,
#      'width': 79.92001342773438,
#      'height': 7.880000114440918,
#      'text': '17 cals per slice'},
#     {'top': 429.63,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '325 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 429.63,
#      'left': 475.44,
#      'width': 63.3599853515625,
#      'height': 7.880000114440918,
#      'text': 'Low Calorie'}],
#    [{'top': 452.07,
#      'left': 101.16,
#      'width': 78.0,
#      'height': 7.880000114440918,
#      'text': 'Cream crackers'},
#     {'top': 452.07,
#      'left': 246.84,
#      'width': 101.27999877929688,
#      'height': 7.880000114440918,
#      'text': '35 cals (per cracker)'},
#     {'top': 452.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '440 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 452.07,
#      'left': 472.68,
#      'width': 69.0,
#      'height': 7.880000114440918,
#      'text': 'Low / portion'}],
#    [{'top': 474.63,
#      'left': 115.32,
#      'width': 49.68000030517578,
#      'height': 7.880000114440918,
#      'text': 'Crumpets'},
#     {'top': 474.63,
#      'left': 244.92,
#      'width': 105.24000549316406,
#      'height': 7.880000114440918,
#      'text': '93 cals (per crumpet)'},
#     {'top': 474.63,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '198 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 474.63,
#      'left': 481.68,
#      'width': 51.0,
#      'height': 7.880000114440918,
#      'text': 'Low-Med'}],
#    [{'top': 497.07,
#      'left': 79.2,
#      'width': 122.04000854492188,
#      'height': 7.880000114440918,
#      'text': 'Flapjacks basic fruit mix'},
#     {'top': 497.07,
#      'left': 276.24,
#      'width': 42.600006103515625,
#      'height': 7.880000114440918,
#      'text': '320 cals'},
#     {'top': 497.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '500 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 497.07,
#      'left': 493.68,
#      'width': 27.0,
#      'height': 7.880000114440918,
#      'text': 'High'}],
#    [{'top': 519.63,
#      'left': 95.16,
#      'width': 90.0,
#      'height': 7.880000114440918,
#      'text': 'Macaroni (boiled)'},
#     {'top': 519.63,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '238 cals (250g)'},
#     {'top': 519.63,
#      'left': 396.48,
#      'width': 36.5999755859375,
#      'height': 7.880000114440918,
#      'text': '95 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 519.63,
#      'left': 476.88,
#      'width': 60.5999755859375,
#      'height': 7.880000114440918,
#      'text': 'Low calorie'}],
#    [{'top': 542.07,
#      'left': 122.04,
#      'width': 36.35999298095703,
#      'height': 7.880000114440918,
#      'text': 'Muesli'},
#     {'top': 542.07,
#      'left': 260.16,
#      'width': 74.63998413085938,
#      'height': 7.880000114440918,
#      'text': '195  cals (50g)'},
#     {'top': 542.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '390 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 542.07,
#      'left': 482.04,
#      'width': 50.279998779296875,
#      'height': 7.880000114440918,
#      'text': 'Med-high'}],
#    [{'top': 564.63,
#      'left': 88.68,
#      'width': 102.95999908447266,
#      'height': 7.880000114440918,
#      'text': 'Naan bread (normal)'},
#     {'top': 564.63,
#      'left': 233.76,
#      'width': 127.56001281738281,
#      'height': 7.880000114440918,
#      'text': '300 cals (small plate size)'},
#     {'top': 564.63,
#      'left': 393.48,
#      'width': 45.5999755859375,
#      'height': 7.880000114440918,
#      'text': '320 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 564.63,
#      'left': 485.28,
#      'width': 43.680023193359375,
#      'height': 7.880000114440918,
#      'text': 'Medium'}],
#    [{'top': 587.07,
#      'left': 98.16,
#      'width': 84.0,
#      'height': 7.880000114440918,
#      'text': 'Noodles (boiled)'},
#     {'top': 587.07,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '175 cals (250g)'},
#     {'top': 587.07,
#      'left': 396.48,
#      'width': 36.5999755859375,
#      'height': 7.880000114440918,
#      'text': '70 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 587.07,
#      'left': 476.88,
#      'width': 60.5999755859375,
#      'height': 7.880000114440918,
#      'text': 'Low calorie'}],
#    [{'top': 609.63,
#      'left': 84.0,
#      'width': 112.32000732421875,
#      'height': 7.880000114440918,
#      'text': 'Pasta ( normal boiled )'},
#     {'top': 609.63,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '330 cals (300g)'},
#     {'top': 609.63,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '110 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 609.63,
#      'left': 476.88,
#      'width': 60.5999755859375,
#      'height': 7.880000114440918,
#      'text': 'Low calorie'}],
#    [{'top': 632.07,
#      'left': 76.2,
#      'width': 127.91999816894531,
#      'height': 7.880000114440918,
#      'text': 'Pasta (wholemeal boiled )'},
#     {'top': 632.07,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '315 cals (300g)'},
#     {'top': 632.07,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '105 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 632.07,
#      'left': 476.88,
#      'width': 60.5999755859375,
#      'height': 7.880000114440918,
#      'text': 'Low calorie'}],
#    [{'top': 654.63,
#      'left': 75.84,
#      'width': 128.63999938964844,
#      'height': 7.880000114440918,
#      'text': 'Porridge oats (with water)'},
#     {'top': 654.63,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '193 cals (350g)'},
#     {'top': 654.63,
#      'left': 396.48,
#      'width': 36.5999755859375,
#      'height': 7.880000114440918,
#      'text': '55 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 654.63,
#      'left': 476.88,
#      'width': 60.5999755859375,
#      'height': 7.880000114440918,
#      'text': 'Low calorie'}],
#    [{'top': 677.43,
#      'left': 91.92,
#      'width': 96.60000610351562,
#      'height': 7.880000114440918,
#      'text': 'Potatoes** (boiled)'},
#     {'top': 677.43,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '210 cals (300g)'},
#     {'top': 677.43,
#      'left': 396.48,
#      'width': 36.5999755859375,
#      'height': 7.880000114440918,
#      'text': '70 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 677.43,
#      'left': 476.88,
#      'width': 60.5999755859375,
#      'height': 7.880000114440918,
#      'text': 'Low calorie'}],
#    [{'top': 700.35,
#      'left': 95.16,
#      'width': 90.0,
#      'height': 7.880000114440918,
#      'text': 'Potatoes** (roast)'},
#     {'top': 700.35,
#      'left': 258.72,
#      'width': 77.63998413085938,
#      'height': 7.880000114440918,
#      'text': '420 cals (300g)'},
#     {'top': 700.35,
#      'left': 393.48,
#      'width': 42.5999755859375,
#      'height': 7.880000114440918,
#      'text': '140 cals'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 700.35,
#      'left': 485.28,
#      'width': 43.680023193359375,
#      'height': 7.880000114440918,
#      'text': 'Medium'}]]}]

# %%
#extracting the table contents from third page
df_page3= read_pdf(r"C:\\Users\\owner\\Desktop\\Food Calories List.pdf",pages=3)
df_page3
# Out:
#                    Fish cake   90 cals per cake  200 cals       Medium
# 0               Fish fingers  50 cals per piece  220 cals       Medium
# 1                     Gammon           320 cals  280 cals     Med-High
# 2              Haddock fresh           200 cals  110 cals  Low calorie
# 3              Halibut fresh           220 cals  125 cals  Low calorie
# 4                        NaN                NaN       NaN          NaN
# 5                        Ham             6 cals  240 cals       Medium
# 6      Herring fresh grilled           300 cals  200 cals       Medium
# 7                     Kidney           200 cals  160 cals       Medium
# 8                     Kipper           200 cals  120 cals  Low calorie
# 9                        NaN                NaN       NaN          NaN
# 10                     Liver           200 cals  150 cals       Medium
# 11                Liver pate           150 cals  300 cals       Medium
# 12              Lamb (roast)           300 cals  300 cals     Med-High
# 13            Lobster boiled           200 cals  100 cals  Low calorie
# 14                       NaN                NaN       NaN          NaN
# 15             Luncheon meat           300 cals  400 cals         High
# 16                  Mackeral           320 cals  300 cals       Medium
# 17                   Mussels            90 cals   90 cals      Low-Med
# 18            Pheasant roast           200 cals  200 cals       Medium
# 19        Pilchards (tinned)           140 cals  140 cals       Medium
# 20                    Prawns           180 cals  100 cals     Low- Med
# 21                      Pork           320 cals  290 cals     Med-High
# 22                  Pork pie           320 cals  450 cals         High
# 23                    Rabbit           200 cals  180 cals       Medium
# 24              Salmon fresh           220 cals  180 cals       Medium
# 25    Sardines tinned in oil           220 cals  220 cals       Medium
# 26  Sardines in tomato sauce           180 cals  180 cals       Medium
# 27        Sausage pork fried           250 cals  320 cals         High
# 28      Sausage pork grilled           220 cals  280 cals     Med-High
# 29              Sausage roll           290 cals  480 cals         High
# 30       Scampi fried in oil           400 cals  340 cals         High
# 31        Steak & kidney pie           400 cals  350 cals         High

# %%
#extracting the table contents from all the pages at once
df_all= read_pdf(r"C:\\Users\\owner\\Desktop\\Food Calories List.pdf",pages="all", multiple_tables=True)
df_all

# %%
#extracting the table contents from a page without any header
df_without_header= read_pdf(r"C:\\Users\\owner\\Desktop\\Food Calories List.pdf", pandas_options={"header":None})
df_without_header
